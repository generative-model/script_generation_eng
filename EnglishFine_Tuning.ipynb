# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
# TensorFlow 1.x selected.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 310Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 47.8Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 291Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:03, 157Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 397Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 141Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 128Mit/s]

# %%
gpt2.mount_gdrive()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_name = "ShortEnglishSentences.txt"

# %%
gpt2.copy_file_from_gdrive(file_name)

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=800,
              restore_from='fresh',
              run_name='run1',
              print_every=10,
              sample_every=200,
              save_every=400
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# 100%|██████████| 1/1 [00:00<00:00, 327.73it/s]
# Loading dataset...
# dataset has 5964 tokens
# Training...
# [10 | 54.38] loss=1.65 avg=1.65
# [20 | 100.22] loss=1.16 avg=1.40
# [30 | 146.08] loss=0.88 avg=1.23
# [40 | 191.90] loss=0.27 avg=0.98
# [50 | 237.66] loss=0.13 avg=0.81
# [60 | 283.43] loss=0.04 avg=0.68
# [70 | 329.21] loss=0.03 avg=0.58
# [80 | 374.97] loss=0.03 avg=0.51
# [90 | 420.74] loss=0.02 avg=0.45
# [100 | 466.56] loss=0.02 avg=0.41
# [110 | 512.37] loss=0.02 avg=0.37
# [120 | 558.09] loss=0.03 avg=0.34
# [130 | 603.91] loss=0.02 avg=0.32
# [140 | 649.72] loss=0.02 avg=0.29
# [150 | 695.55] loss=0.02 avg=0.27
# [160 | 741.38] loss=0.02 avg=0.26
# [170 | 787.19] loss=0.02 avg=0.24
# [180 | 832.97] loss=0.02 avg=0.23
# [190 | 878.63] loss=0.02 avg=0.22
# [200 | 924.34] loss=0.02 avg=0.21
# ======== SAMPLE 1 ========
#  Pat Heimdall was born in New York City, a half-ass in his clothes
# ．
# 304. He lived in luxury
# ．
# 305. He really enjoyed himself
# ．
# 306. He is physically mature
# ．
# 307. I am busy How is your business?
# 308. I don't think much of the movie
# ．
# 309. I feel like eating an ice-cream
# ．
# 310. I found him seated on the bench
# ．
# 311. I gave much time to the old car
# ．
# 312. I lost the door key about here.
# 313. I'm not guessing I really know
# ．
# 314. It's time to tell her the truth
# ．
# 315. Let's watch TV with a candle on
# ．
# 316. Most games cost about that much
# ．
# 317. My parents want me to go abroad
# ．
# 318. She has been collecting stamps
# ．
# 319. The figure seems all Right
# ．
# 320. The stars are too far away
# ．
# 321. There go the house lights
# ．
# 322. They are all On her
# ．
# 323. They're in the style line
# ．
# 324. They go with me
# ．
# 325. Go right back to the beginning
# ．
# 326. He has a remarkable memory
# ．
# 327. He won an election
# ．
# 328. I am Idriss
# ．
# 329. I felt no regret for it
# ．
# 330. I get up at six o'clock
# ．
# 331. I meet the boss himself
# ．
# 332. I owe you for my dinner.
# 333. I really enjoyed myself
# ．
# 334. I'm fed up with my work!
# 335. It's no use complaining.
# 336. She's under the weather
# ．
# 337. The child sobbed sadly
# ．
# 338. The rumor had no basis
# ．
# 339. They praised him highly
# ．
# 340. Winter is a cold season.
# 341. You can call me any time
# ．
# 342. 15 divided by3 equals 5
# ．
# 343. All for one
# ，one for all
# ．
# 344. East,west
# ，home is best
# ．
# 345. He grasped both my hands.
# 346. He is physically mature
# ．
# 347. I am afraid that l have to go
# ．
# 348. I don't have any cash with me
# ．
# 349. I have a large collection of CDs
# ．
# 350. I went there three days ago
# ．
# 351. I won't be able to see him today
# ．
# 352. I'll call a taxi in case of need
# ．
# 353. I'm very glad to hear that
# ．
# 354. It is not so easy as you think
# ．
# 355. It's true what you saying.
# 356. It's very kind of you to help me
# ．
# 357. I begin by explaining myself
# ．
# 358. I felt no regret for it
# ．
# 359. I lose the point when I make it
# ．
# 360. I'm not sure I can make it
# ．
# 361. I quit my job to focus on my business
# ．
# 362. Iilva!
# 363. I am a football fan
# ．
# 364. I Am Not A Bridgetor
# ．
# 365. I Am You, Mr.Wang
# ．
# 366. I Am you Older than you
# ．
# 367. I Did It Myself
# ．
# 368. I Do Want To See To'
# 369. I Quit My Job To Focus On Business
# ．
# 370. It's None of Your Business!
# 371. It's None of Your Business's Business!
# 372. May I Use Your Title?
# 373. She's A Good Girl.
# 374. She's in her everyday clothes.
# 375. She's in her own shoes.
# 376. Someone is ringing the bell.
# 377. The Smiths are my neighbors.
# 378. These shoes don't fit right.
# 379. This is only the first half.
# 380. This pen doesn't write well.
# 381. This work itself is very easy.
# 382. This pen feels pain in my hand.
# 383. Would you like a cup of tea?
# 384. You really look sharp today
# ．
#
# [210 | 988.74] loss=0.02 avg=0.20
# [220 | 1034.53] loss=0.02 avg=0.19
# [230 | 1080.35] loss=0.03 avg=0.18
# [240 | 1126.04] loss=0.02 avg=0.17
# [250 | 1171.85] loss=0.02 avg=0.16
# [260 | 1217.63] loss=0.02 avg=0.16
# [270 | 1263.38] loss=0.02 avg=0.15
# [280 | 1309.21] loss=0.01 avg=0.15
# [290 | 1355.03] loss=0.01 avg=0.14
# [300 | 1400.80] loss=0.01 avg=0.14
# [310 | 1446.56] loss=0.01 avg=0.13
# [320 | 1492.38] loss=0.01 avg=0.13
# [330 | 1538.15] loss=0.02 avg=0.12
# [340 | 1583.92] loss=0.02 avg=0.12
# [350 | 1629.70] loss=0.02 avg=0.12
# [360 | 1675.52] loss=0.02 avg=0.11
# [370 | 1721.32] loss=0.02 avg=0.11
# [380 | 1767.12] loss=0.02 avg=0.11
# [390 | 1812.94] loss=0.01 avg=0.10
# [400 | 1858.72] loss=0.02 avg=0.10
# Saving checkpoint/run1/model-400
# ======== SAMPLE 1 ========
#  careful.
# 139. What day is today?
# 140. What do you think?
# 141. Who told you that?
# 142. Who's kicking off?
# 143. Yes,
# I suppose So
# ．
# 144. You can't miss it
# 145. Any messages for me?
# 146. Don't be so modest
# ．
# 147. Don't give me that!
# 148. He is a smart boy
# ．
# 149. He is just a child
# ．
# 150. I can't follow you
# ．
# 151. I felt sort of ill.
# 152. I have a good idea!
# 153. It is growing cool
# ．
# 154. It seems all right
# ．
# 155. It's going too far
# ．
# 156. May I use your pen?
# 157. She had a bad cold
# ．
# 158. That's a good idea
# ．
# 159. The answer is zero
# ．
# 160. What does she like?
# 161. As soon as possible!
# 162. He can hardly speak
# ．
# 163. He always talks big
# ．
# 164. He won an election
# ．
# 165. I am a football fan
# ．
# 166. If only I could fly
# ．
# 167. I'll be right there
# ．
# 168. I'll see you at six
# ．
# 169. Is it true or false?
# 170. Just read it for me
# ．
# 171. Knowledge is power
# ．
# 172. Move out of my way!
# 173. Time is running out
# ．
# 174. We are good friends
# ．
# 175. What's your trouble?
# 176. You did fairly well!
# 177. Clothes make the man
# ．
# 178. Did you miss the bus?
# 179. Don't lose your head
# ．
# 180. He can't take a joke
# ．
# 181. He owes my uncle $100
# ．
# 182. How are things going?
# 183. How are you recently?
# 184. I know all about it
# ．
# 185. It really takes time
# ．
# 186. It's against the law
# ．
# 187. Love me, love my dog
# ．
# 188. My mouth is watering
# ．
# 189. Speak louder please
# ．
# 190. This boy has no job
# ．
# 191. This house is my own
# ．
# 192. What happened to you?
# 193. You are just in time.
# 194. You need to work out
# ．
# 195. Your hand feels cold
# ．
# 196. Don't be so childish.
# 197. Don't trust to chance!
# 198. Fasten your seat belt
# ．
# 199. He has a large income.
# 200. He looks very healthy
# ．
# 201. He paused for a reply
# ．
# 202. He repaired his house
# ．
# 203. He suggested a picnic.
# 204. He suggested a bike ride.
# 205. Here's a gift for you
# ．
# 206. How much does it cost?
# 207. I caught the last bus.
# 208. I could hardly speak
# ．
# 209. I'll have to try that
# ．
# 210. I'm very proud of you
# ．
# 211. It doesn't make sense.
# 212. Make yourself at home
# ．
# 213. My car needs washing
# ．
# 214. None of your business!
# 215. Not a sound was heard.
# 216. That's always the case
# ．
# 217. The road divides here.
# 218. Those are watermelons
# ．
# 219. What a nice day it is!
# 220. What's wrong with you?
# 221. You are a chicken
# ．
# 222. A beautiful day
# ，isn't it?
# 223. He is collecting money
# ．
# 224. He was born in New York
# ．
# 225. He was not a bit tired
# ．
# 226. I will be more careful
# ．
# 227. I will never forget it
# ．
# 228. It is Just what I need
# ．
# 229. It rather surprised me
# ．
# 230. It rather surprised you
# ．
# 231. Can I help you?
# 232. Don't be so childish.
# 233. Don't trust to chance!
# 234. Fasten your seat belt
# ．
# 235. He is a smart
#
# [410 | 1924.87] loss=0.01 avg=0.10
# [420 | 1970.65] loss=0.02 avg=0.10
# [430 | 2016.46] loss=0.02 avg=0.09
# [440 | 2062.29] loss=0.01 avg=0.09
# [450 | 2108.06] loss=0.02 avg=0.09
# [460 | 2153.77] loss=0.01 avg=0.09
# [470 | 2199.49] loss=0.01 avg=0.09
# [480 | 2245.20] loss=0.02 avg=0.08
# [490 | 2290.89] loss=0.02 avg=0.08
# [500 | 2336.64] loss=0.01 avg=0.08
# [510 | 2382.34] loss=0.01 avg=0.08
# [520 | 2428.08] loss=0.01 avg=0.08
# [530 | 2473.79] loss=0.01 avg=0.08
# [540 | 2519.51] loss=0.02 avg=0.07
# [550 | 2565.28] loss=0.02 avg=0.07
# [560 | 2611.05] loss=0.02 avg=0.07
# [570 | 2656.76] loss=0.01 avg=0.07
# [580 | 2702.56] loss=0.02 avg=0.07
# [590 | 2748.30] loss=0.02 avg=0.07
# [600 | 2794.06] loss=0.02 avg=0.07
# ======== SAMPLE 1 ========
# ．
# 351. I saw it with my own eyes
# ．
# 352. I will arrange everything
# ．
# 353. I wish I knew my neighbor
# ．
# 354. I will check out．
# 355. I wish I lived in NEWYORK．
# 356. I'm very proud of you
# ．
# 357. I wish I lived in NEWYORKYORK．
# 358. I'll meet you there．
# 359. Let me see you.
# 360. My mouth is watering
# ．
# 361. Speak louder please
# ．
# 362. This boy has no job
# ．
# 363. This house is my own
# ．
# 364. What happened to you?
# 365. You are just in time.
# 366. You need to work out
# ．
# 367. Your hand feels cold
# ．
# 368. She is a composer for the harp．
# 369. A lovely day
# ，isn't it?
# 370. He is collecting money
# ．
# 371. He was born in New York．
# 372. He was not a bit tired．
# 373. He was not a bit tired．
# 374. He is the happiest man alive.
# 375. He was not a bit angry．
# 376. His looks are always funny．
# 377. How about going to a movie?
# 378. I think I've caught a cold．
# 379. I was taking care of Sally.
# 380. I wish I lived in NEWYORK．
# 381. I'm very glad to hear that．
# 382. I'm your lucky fellow then.
# 383. It's none of your business!
# 384. No littering on the campus．
# 385. She is a composer for the harp．
# 386. She was not a bit tired．
# 387. She ran her business cards up the wall．
# 388. She knit her own tools．
# 389. She was not a little tired．
# 390. Someone is ringing the bell．
# 391. The Smiths are my neighbors.
# 392. These shoes don't fit right．
# 393. This is only the first half．
# 394. This pen doesn't write well．
# 395. Would you like a cup of tea?
# 396. You really look sharp today．
# 397. Another cat came to my house．
# 398. Check your answers with mine．
# 399. Don't keep the truth from me．
# 400. Everything has its beginning．
# 401. He came to the point at once．
# 402. He fell behind with his work．
# 403. He is the happiest man alive.
# 404. He fell behind with his work．
# 405. He is the happiest man alive.
# 406. He made it!
# 407. He won an election
# ．
# 408. I am afraid that l have to go．
# 409. I don't have any cash with me．
# 410. I have been putting on weight．
# 411. I have just finished the book．
# 412. I was late for work yesterday，
# 413. It appears to be a true story．
# 414. It's very thoughtful of you．
# 415. May I speak to Lora，please?
# 416. You can either stay or leave．
# 417. Your life is your own affair．
# 418. All that glitters is not gold．
# 419. Are you going to have a party?
# 420. Aren't you concerned about it?
# 421. Don't forget to keep in touch．
# 422. He broke his words once again.
# 423. He is in his everyday clothes．
# 424. He is taller than I buy ahead．
# 425. He led them down the mountain．
# 426. He was trained to be a lawyer．
# 427. I am afraid that l have to go．
# 428. I don't have any cash with me．
# 429. I have just finished the book．
# 430. I'm afraid that l have to go．
# 431. John asked Grace to marry him，
# 432. My life is your own affair．
# 433. My false teeth are stuck to it．
# 434. She is a composer for the harp．
# 435. Sally is a dancer for the harp．
# 436. Supper is ready at six
#
# [610 | 2857.06] loss=0.01 avg=0.07
# [620 | 2902.81] loss=0.01 avg=0.06
# [630 | 2948.59] loss=0.01 avg=0.06
# [640 | 2994.28] loss=0.02 avg=0.06
# [650 | 3040.08] loss=0.01 avg=0.06
# [660 | 3085.80] loss=0.01 avg=0.06
# [670 | 3131.53] loss=0.01 avg=0.06
# [680 | 3177.24] loss=0.02 avg=0.06
# [690 | 3222.96] loss=0.01 avg=0.06
# [700 | 3268.68] loss=0.01 avg=0.06
# [710 | 3314.48] loss=0.01 avg=0.06
# [720 | 3360.31] loss=0.01 avg=0.05
# [730 | 3406.03] loss=0.01 avg=0.05
# [740 | 3451.76] loss=0.01 avg=0.05
# [750 | 3497.52] loss=0.01 avg=0.05
# [760 | 3543.24] loss=0.01 avg=0.05
# [770 | 3588.95] loss=0.01 avg=0.05
# [780 | 3634.71] loss=0.01 avg=0.05
# [790 | 3680.45] loss=0.02 avg=0.05
# [800 | 3726.20] loss=0.01 avg=0.05
# Saving checkpoint/run1/model-800
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='run1')

# %%
#안하면 밑에꺼 오류남..
import tensorflow as tf
tf.reset_default_graph()
sess = gpt2.start_tf_sess()

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='run1')
# Out:
# Loading checkpoint checkpoint/run1/model-800
# INFO:tensorflow:Restoring parameters from checkpoint/run1/model-800

# %%
gpt2.generate(sess, run_name='run1')
# Out:
# ．
# 210. I'm fed up with my work!
# 211. It's no use complaining.
# 212. She's under the weather
# ．
# 213. The child sobbed sadly
# ．
# 214. The rumor had no basis
# ．
# 215. They praised him highly
# ．
# 216. They'll give me a ring
# ．
# 217. Things are getting better
# ．
# 218. Wake me up at five thirty
# ．
# 219. We are divided in our opinions
# ．
# 220. We all desire happiness.
# 221. We just caught the plane
# ．
# 222. What shall we do tonight?
# 223. What's your goal in life
# ．
# 224. When was the house built?
# 225. Why did you stay at home?
# 226. Would you like some help?
# 227. You mustn't aim too high
# ．
# 228. You're really killing me!
# 229. You've got a point there
# ．
# 230. Being criticized is awful!
# 231. Did you enter the contest?
# 232. Do you accept credit cards?
# 233. Don't cry over spilt milk
# ．
# 234. Don't let chances pass by
# ．
# 235. He owned himself defeated
# ．
# 236. He seems at little nervous
# ．
# 237. He strolls about the town
# ．
# 238. Her tooth ached all night.
# 239. How about a drink tonight?
# 240. I can do nothing but that.
# 241. I get hold of you at last
# ．
# 242. I have a surprise for you
# ．
# 243. I like all kinds of fruit
# ．
# 244. I saw it with my own eyes
# ．
# 245. I will arrange everything
# ．
# 246. I wish I knew my neighbor
# ．
# 247. I would like to check out．
# 248. I've got too much work to do．
# 249. Let's go for a walk, shall we?
# 250. Please let me check the bill．
# 251. Plenty of sleep is healthful．
# 252. We are good friends
# ．
# 253. What's your trouble?
# 254. You did fairly well!
# 255. Clothes make the man
# ．
# 256. Did you miss the bus?
# 257. Don't lose your head
# ．
# 258. He can't take a joke
# ．
# 259. He owes my uncle $100
# ．
# 260. How are things going?
# 261. How are you recently?
# 262. I know all about it
# ．
# 263. It really takes time
# ．
# 264. It's against the law
# ．
# 265. Love me, love my dog
# ．
# 266. My mouth is watering
# ．
# 267. Speak louder please
# ．
# 268. This boy has no job
# ．
# 269. This house is my own
# ．
# 270. What happened to you?
# 271. You are just in time.
# 272. You need to work out
# ．
# 273. Your hand feels cold
# ．
# 274. Don't be so childish.
# 275. Don't trust to chance!
# 276. Fasten your seat belt
# ．
# 277. He has a large income.
# 278. He looks very healthy
# ．
# 279. He paused for a reply
# ．
# 280. He repaired his house
# ．
# 281. He suggested a picnic.
# 282. He suggested a job
# ．
# 283. He suggested a trip to the vet
# ．
# 284. Here's a gift for you
# ．
# 285. How much does it cost?
# 286. I caught the last bus.
# 287. I could hardly speak
# ．
# 288. I'll have to try that
# ．
# 289. I'm very proud of you
# ．
# 290. It doesn't make sense.
# 291. It's Sunday today.
# 292. Make yourself at home
# ．
# 293. My car needs washing
# ．
# 294. None of your business!
# 295. Not a sound was heard.
# 296. She is a composer for the harp
# ．
# 297. Take me to the airport please．
# 298. Talking with you is a pleasure.
# 299. The eggs are sold by the dozen．
# 300. The price just covers the cost．
# 301. The sweater is of good quality.

# %%
gpt2.generate(sess,
              length=250,
              temperature=0.7,
              nsamples=5,
              batch_size=5,
              prefix="<|startoftext|>",
              truncate="<|endoftext|>",
              include_prefix=False
              )
# Out:
# <|startoftext|>
#
# 218. It's going too far
# ．
# 219. May I use your pen?
# 220. She had a bad cold
# ．
# 221. That's a good idea
# ．
# 222. The answer is zero
# ．
# 223. What does she like?
# 224. As soon as possible!
# 225. He can hardly speak
# ．
# 226. He always talks big
# ．
# 227. He won an election
# ．
# 228. I'm your lucky fellow then.
# 229. It's none of your business!
# 230. No littering on the campus
# ．
# 231. She is a good-looking girl.
# 232. She shared a bed with her brother
# ．
# 233. She hired a car by the hour
# ．
# 234. So I just take what I want
# ．
# 235. Spring is a pretty season
# ，
# 236. The figure seems all Right
# ．
# 237. The stars are too far away
# ．
# 238. They're too far away
# ．
# 239. We all desire happiness.
#
# ====================
# <|startoftext|>
#
# I agree
# Not bad
# Not yet
# See you
# Shut up!
# So long
# Why not?
# Allow me.
# Be quiet!
# Cheer up
# !
# Good job
# !
# Have fun
# !
# How much
# ?
# I'm full
# ．
# I'm home
# ．
# I'm lost
# ．
# My treat
# ．
# So do I
# ．
# This way
# .
# After you
# ．
# Bless you
# !
# Follow me
# ．
# Forget it
# !
# Good luck
# !
# I decline
# !
# I promise
# ．
# Of course
# !
# Slow down
# !
# Take care
# !
# They hurt
# ．
# Try again
# ．
# Watch out
# !
# What's up
# ?
# Be careful
# !
# Bottoms up!
# Don't move!
# Guess what?
# I doubt it
# I think so
# I'm single
# Keep it up!
# Let me see
# Never mind
# No problem !
# That's all !
# 101. It sounds great!
# 102. It's a fine day
# 103
# ====================
# <|startoftext|>
#
# 113. I'll check it out
# ．
# 114. I'm very proud of you
# ．
# 115. It's a long story
# ．
# 116. It's Sunday today
# ．
# 117. Just wait and see!
# 118. Make up your mind
# ．
# 119. That's all I need
# ．
# 120. The view is great
# ．
# 121. The wall has ears
# ．
# 122. There comes a bus
# ．
# 123. What day is today?
# 124. What do you think?
# 125. Who told you that?
# 126. Who's kicking off?
# 127. Yes,
# I suppose So
# ．
# 128. You can't miss it
# ．
# 129. Any messages for me?
# 130. Don't be so modest
# ．
# 131. Don't give me that!
# 132. He is a smart boy
# ．
# 133. He is just a child
# ．
# 134. I can't follow you
# ．
# 135. I felt sort of ill.
# 136. I have a
# ====================
# <|startoftext|>
#
# 148. Are you going to have a party?
# 149. Aren't you concerned about it?
# 150. Don't forget to keep in touch．
# 151. He broke his words once again.
# 152. He is in his everyday clothes．
# 153. He is taller than I buy ahead．
# 154. He led them down the mountain．
# 155. He was trained to be a lawyer．
# 156. I am afraid that l have to go．
# 157. I don't have any cash with me．
# 158. I have been putting on weight．
# 159. I have just finished the book．
# 160. I was late for work yesterday，
# 161. It appears to be a true story．
# 162. I've got to start working out．
# 163. Japan is to the east of China．
# 164. John asked Grace to marry him，
# 165. My watch is faster than yours．
# 166. New China was founded in l949．
# 167. Thanks for your flattering me．
# 168. They
# ====================
# <|startoftext|>
#
# I'm lost
# ．
# My treat
# ．
# So do I
# ．
# This way
# .
# After you
# ．
# Bless you
# !
#
# Follow me
# ．
# Forget it
# !
# Good luck
# !
# I decline
# !
# I promise
# ．
# Of course
# !
# Slow down
# !
# Take care
# !
# They hurt
# ．
# Try again
# ．
# Watch out
# !
# What's up
# ?
# Be careful
# !
# Bottoms up!
# Don't move!
# Guess what?
# I doubt it
# I think so
# I'm single
# Keep it up!
# Let me see
# Never mind
# No problem !
# That's all !
# 101. It sounds great!
# 102. It's a fine day
# 103. So far
# ，So good
# ．
# 104. What time is it?
# 105. You can make it!
# 106. Control yourself!
# 107. He came by train
# ．
# 108. He is ill in bed
# ．
# 109. He lacks courage
# �
# ====================
